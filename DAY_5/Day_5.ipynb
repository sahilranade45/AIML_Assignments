# %% [markdown]
# """
# Name: Sahil Ranade
# Batch: AIML
# Day: 5 (13th August 2026)
# Assignment: 5
#
# Description:
# Python type hints, function return type hints, union types,
# collection type hints, classes, objects, attributes, constructors,
# self, methods, instance and class attributes, and special methods.
# """

# %%
def add(a,b):
  return a+b

add(10,20)
# Out:
# 30

# %% [markdown]
# TYPE HINTS -hinting the user what is expected
# syntax : var_name:type = value

# %%
def add(a:int,b:int):
  return a+b

add(10,20)
# Out:
# 30

# %%
name : str = "sahil"
age : int = 19
height : float =5.7
is_student : bool = True

# %%
#Hinting what a function should return
def square(num:int) -> int:
  return num*num

square(10)

# %%
#When more than one type is ok
def print(user_id:int|str):
    return user_id

print(101)
print("A1001")
# Out:
# 'A1001'

# %%
#hinting whats inside a collection
numbers:list[int]=[10,20,30]
std_marks:dict[str,int]={"sahil":30}
point:tuple[int,int]=(10,20)

# %% [markdown]
# Type hints are never enforced to runtime .
# Never throw error even if there is a mismatch.
# They are better understanding and documentations.

# %%
def double(num:int) -> int:
  return num*2
double("hi")
# Out:
# 'hihi'

# %%
def calculate_average(marks:list[int]) ->float:
  return sum(marks)/len(marks)
def display_student(name:str,marks:list[int]) ->None:
  average:float=calculate_average(marks)
  print(f"Student:{name}")
  print(f"Average:{average:2f}")
display_student("sahil",[90,80,70])
# Out:
# Student:sahil
# Average:80.000000

# %% [markdown]
# Class - blueprint
#
# Object - things built from it

# %%
class Student:  #Student is a class
  pass
student1=Student() #student1 is a object of class Student
student2=Student()

#Attributes
student1.name:str="sahil"
student1.age:int=19
student1.marks:list[int]=[90,80,70]
print(student1.name)
print(student1.age)
print(student1.marks)
# Out:
# sahil
# 19
# [90, 80, 70]

# %%
#_init_() - setting up a new object
#self - it refers to the obj a method is running on - its how each instance keeps its own separate values

class Student:
  def __init__(self,name:str,age:int):
    self.name=name
    self.age=age
student=Student("sahil",19)
std=Student("rohan",18)
print(student.name)
print(student.age)
print(std.name)
print(std.age)
# Out:
# sahil
# 19
# rohan
# 18

# %% [markdown]
# **Method** - **function** **inside** **class**

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def introduce(self):
        print(f"My name is {self.name}")
        print(f"My age is {self.age}")


student = Student("Sahil", 20)
student.introduce()
# Out:
# My name is Sahil
# My age is 20

# %% [markdown]
# Instance attribute - belongs to one object
#
# Class attribute - share to every object .

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
        else:
            print("Insufficient balance")

    def show_balance(self):
        print(f"Balance for {self.owner} is {self.balance}")


account = BankAccount("Sahil", 1000)
account.deposit(500)
account.withdraw(200)
account.show_balance()
# Out:
# Balance for Sahil is 1300

# %%
#Special (Dunder) Method - methods with underscore on both sides

class Student:
    def __init__(self, name):
        self.name = name

    def __str__(self):
        return f"{self.name}"

    def __repr__(self):
        return f"Student({self.name!r})"

    def __len__(self):
        return len(self.name)

    def _eq_(self, other):
        return self.name == other.name

student1==student2


student = Student("Sahil")

print(student)
print(repr(student))
print(len(student))
# Out:
# Sahil
# Student('Sahil')
# 5
